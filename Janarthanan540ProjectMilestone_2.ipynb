# %% [markdown]
# #  DSC540-T302 Data Preparation  #
#
# ## Project Milestone 2 ##
#
# ### Saravanan Janarthanan ###
#
# -------------

# %%
# Load numpy and pandas modules
import pandas as pd
import numpy as py

# %%
#  Load the data file in a dataframe
sp500_df = pd.read_csv('SNP_500_Performance_data.csv')
sp500_df.head()
# Out:
#   Symbol                  Name    Market Cap    P/E    EPS   Net Income  Beta  \
# 0      A  Agilent Technologies  4.223508e+10  26.32   5.37   1240000000  1.11
# 1    AAL  American Airlines Gp  9.009457e+09   5.24   2.64    822000000  1.57
# 2   AAPL             Apple Inc  2.620000e+12  26.30   6.42  96995000000  1.27
# 3   ABBV            Abbvie Inc  3.010000e+11  15.11  11.11   4863000000  0.58
# 4   ABNB       Airbnb Inc Cl A  1.050000e+11  36.85   4.31   4792000000  1.25
#
#    Dividend Div Yield  Extended Hr Last Price  ...  52W Low 52W High  \
# 0     0.922     0.64%                  144.12  ...    96.80   151.58
# 1       NaN     0.00%                   13.75  ...    10.86    19.08
# 2     0.960     0.57%                  169.47  ...   159.78   199.62
# 3     5.990     3.52%                  169.99  ...   130.96   182.89
# 4       NaN     0.00%                  161.77  ...   103.55   170.10
#
#   Wtd Alpha  YTD %Chg  1M %Chg 3M %Chg 52W %Chg                 Sector  \
# 0     12.11     3.66%   -0.16%  10.39%    4.37%      Health Technology
# 1      2.39     0.15%   -6.20%   1.18%   -0.94%         Transportation
# 2     -3.00   -11.92%   -0.32%  -6.40%    3.55%  Electronic Technology
# 3     10.74     9.70%   -5.11%   4.85%    5.72%      Health Technology
# 4     43.69    18.83%    1.53%  18.97%   40.25%      Consumer Services
#
#            ISIN    Volume
# 0  US00846U1016   1.656?M
# 1  US02376R1023  30.632?M
# 2  US0378331005  42.104?M
# 3  US00287Y1091    7.03?M
# 4  US0090661010   2.226?M
#
# [5 rows x 30 columns]

# %% [markdown]
# **Step #1-  Change header**
#
# - View the header names
# - identfy the ones that needs to be changed
# - Retrieve the current headers in a list
# - Perform the changes to the identified headers in the list
# - Set the new headers using the modfiied list values

# %%
header_nms = sp500_df.columns.tolist()
for idx, hdr in enumerate(header_nms):
    print(idx, " : ", hdr)
# Out:
# 0  :  Symbol
# 1  :  Name
# 2  :  Market Cap
# 3  :  P/E
# 4  :  EPS
# 5  :  Net Income
# 6  :  Beta
# 7  :  Dividend
# 8  :  Div Yield
# 9  :  Extended Hr Last Price
# 10  :  Extended Hr Change
# 11  :  %Chg (Ext)
# 12  :  Time
# 13  :  Last Price
# 14  :  Change
# 15  :  %Chg
# 16  :  Opinion
# 17  :  20D Rel Str
# 18  :  20D His Vol
# 19  :  20D Avg Vol
# 20  :  52W Low
# 21  :  52W High
# 22  :  Wtd Alpha
# 23  :  YTD %Chg
# 24  :  1M %Chg
# 25  :  3M %Chg
# 26  :  52W %Chg
# 27  :  Sector
# 28  :  ISIN
# 29  :  Volume

# %%
# Change 4th column (index 3) header from "P/E" to "Price Earnings"
# Change 12th column (index 11) header from "%Chg (Ext)" to "Extended Hr %Change" 
# Change 18th column (index 17) header from "20D Rel Str" to "20D Relative Strength"

header_nms[3] = "Price Earnings"
header_nms[11] = "Extended Hr %Change"
header_nms[17] = "20D Relative Strength"

sp500_df.columns = header_nms
for idx, hdr in enumerate(header_nms):
    print(idx, " : ", hdr)
# Out:
# 0  :  Symbol
# 1  :  Name
# 2  :  Market Cap
# 3  :  Price Earnings
# 4  :  EPS
# 5  :  Net Income
# 6  :  Beta
# 7  :  Dividend
# 8  :  Div Yield
# 9  :  Extended Hr Last Price
# 10  :  Extended Hr Change
# 11  :  Extended Hr %Change
# 12  :  Time
# 13  :  Last Price
# 14  :  Change
# 15  :  %Chg
# 16  :  Opinion
# 17  :  20D Relative Strength
# 18  :  20D His Vol
# 19  :  20D Avg Vol
# 20  :  52W Low
# 21  :  52W High
# 22  :  Wtd Alpha
# 23  :  YTD %Chg
# 24  :  1M %Chg
# 25  :  3M %Chg
# 26  :  52W %Chg
# 27  :  Sector
# 28  :  ISIN
# 29  :  Volume

# %%
sp500_df.head()
# Out:
#   Symbol                  Name    Market Cap  Price Earnings    EPS  \
# 0      A  Agilent Technologies  4.223508e+10           26.32   5.37
# 1    AAL  American Airlines Gp  9.009457e+09            5.24   2.64
# 2   AAPL             Apple Inc  2.620000e+12           26.30   6.42
# 3   ABBV            Abbvie Inc  3.010000e+11           15.11  11.11
# 4   ABNB       Airbnb Inc Cl A  1.050000e+11           36.85   4.31
#
#     Net Income  Beta  Dividend Div Yield  Extended Hr Last Price  ...  \
# 0   1240000000  1.11     0.922     0.64%                  144.12  ...
# 1    822000000  1.57       NaN     0.00%                   13.75  ...
# 2  96995000000  1.27     0.960     0.57%                  169.47  ...
# 3   4863000000  0.58     5.990     3.52%                  169.99  ...
# 4   4792000000  1.25       NaN     0.00%                  161.77  ...
#
#    52W Low 52W High Wtd Alpha  YTD %Chg  1M %Chg 3M %Chg 52W %Chg  \
# 0    96.80   151.58     12.11     3.66%   -0.16%  10.39%    4.37%
# 1    10.86    19.08      2.39     0.15%   -6.20%   1.18%   -0.94%
# 2   159.78   199.62     -3.00   -11.92%   -0.32%  -6.40%    3.55%
# 3   130.96   182.89     10.74     9.70%   -5.11%   4.85%    5.72%
# 4   103.55   170.10     43.69    18.83%    1.53%  18.97%   40.25%
#
#                   Sector          ISIN    Volume
# 0      Health Technology  US00846U1016   1.656?M
# 1         Transportation  US02376R1023  30.632?M
# 2  Electronic Technology  US0378331005  42.104?M
# 3      Health Technology  US00287Y1091    7.03?M
# 4      Consumer Services  US0090661010   2.226?M
#
# [5 rows x 30 columns]

# %% [markdown]
# -----------

# %% [markdown]
# **Step #2 - Find NAN in columns**
#
# - Identify the NAN or null values count present in each column
# - If the column is a key column and analyze and remove those records

# %%
sp500_df.isna().sum()
# Out:
# Symbol                     0
# Name                       0
# Market Cap                 0
# Price Earnings             0
# EPS                        0
# Net Income                 0
# Beta                       2
# Dividend                  99
# Div Yield                  0
# Extended Hr Last Price     0
# Extended Hr Change         0
# Extended Hr %Change        0
# Time                       0
# Last Price                 0
# Change                     0
# %Chg                       0
# Opinion                    1
# 20D Relative Strength      0
# 20D His Vol                0
# 20D Avg Vol                0
# 52W Low                    0
# 52W High                   0
# Wtd Alpha                  0
# YTD %Chg                   0
# 1M %Chg                    0
# 3M %Chg                    0
# 52W %Chg                   2
# Sector                     0
# ISIN                       0
# Volume                     0
# dtype: int64

# %%
sp500_df.isnull().sum()
# Out:
# Symbol                     0
# Name                       0
# Market Cap                 0
# Price Earnings             0
# EPS                        0
# Net Income                 0
# Beta                       2
# Dividend                  99
# Div Yield                  0
# Extended Hr Last Price     0
# Extended Hr Change         0
# Extended Hr %Change        0
# Time                       0
# Last Price                 0
# Change                     0
# %Chg                       0
# Opinion                    1
# 20D Relative Strength      0
# 20D His Vol                0
# 20D Avg Vol                0
# 52W Low                    0
# 52W High                   0
# Wtd Alpha                  0
# YTD %Chg                   0
# 1M %Chg                    0
# 3M %Chg                    0
# 52W %Chg                   2
# Sector                     0
# ISIN                       0
# Volume                     0
# dtype: int64

# %% [markdown]
# **None of the key columns, like 'Symbol', 'Name' or 'Last Price' ,  'Change', '%Chg' have null or NAN values,  hence no records are removed or deleted**
#
# -------

# %% [markdown]
# **Step #3 - Convert float number to int64 to remove expontential listing or displaying**
#
# - Column 'Market Cap'  displays in exponential form that impacts readability.
# - Convert that column values to integer 64 base to display the whole numbers

# %%
sp500_df["Market Cap"].head(10)
# Out:
# 0    4.223508e+10
# 1    9.009457e+09
# 2    2.620000e+12
# 3    3.010000e+11
# 4    1.050000e+11
# 5    1.930000e+11
# 6    3.560126e+10
# 7    2.230000e+11
# 8    2.170000e+11
# 9    9.658304e+10
# Name: Market Cap, dtype: float64

# %%
sp500_df["Market Cap"] =  sp500_df["Market Cap"].astype('int64')

# %%
sp500_df["Market Cap"].head(10)
# Out:
# 0      42235084000
# 1       9009457000
# 2    2620000000000
# 3     301000000000
# 4     105000000000
# 5     193000000000
# 6      35601260000
# 7     223000000000
# 8     217000000000
# 9      96583040000
# Name: Market Cap, dtype: int64

# %% [markdown]
# -------
# **Step #4 - Replace  special character,  replace  with  a no character or null character**
#
# - Column 'Volume' has '?' character in betweeen the values
# - Use the String replace method to replace the '?' character with ''
# - Print the column values to validate

# %%
sp500_df["Volume"].head(10)
# Out:
# 0     1.656?M
# 1    30.632?M
# 2    42.104?M
# 3      7.03?M
# 4     2.226?M
# 5     5.591?M
# 6     2.591?M
# 7     3.695?M
# 8     4.973?M
# 9     2.087?M
# Name: Volume, dtype: object

# %%
sp500_df['Volume'] = sp500_df['Volume'].str.replace('?', '')

# %%
sp500_df["Volume"].head(25)
# Out:
# 0       1.656M
# 1      30.632M
# 2      42.104M
# 3        7.03M
# 4       2.226M
# 5       5.591M
# 6       2.591M
# 7       3.695M
# 8       4.973M
# 9       2.087M
# 10      3.348M
# 11       1.42M
# 12       1.33M
# 13      1.585M
# 14      2.432M
# 15      7.587M
# 16      1.888M
# 17          3M
# 18    355.516K
# 19    690.763K
# 20      919.2K
# 21      1.901M
# 22    595.357K
# 23    999.024K
# 24    351.903K
# Name: Volume, dtype: object

# %% [markdown]
# **Step #5 introduce a new column derive based on 'Opinion' column value**
#
#
# - Convert the confidence percentage into a number rating betweeen 1 to 10)
# - For Buy confidence signal convert it to a psotive integer between  1 to 10  and
# - for Sell signal  convert it to a negative integer ranging between 1 to 10
# - Create a method to recieve the  stirng value and split them and identify the 'Buy'  or'Sell'  value and use it to denote positive or negative rating
# -  use the magnitude value to convert % to 1 to 10 range value

# %%
import math

# Declare a method to process the input string and return a postive or negative rating value from 1 to 10
def convertOpinionBuySellToratingScale(x):
    if x == "" or  type(x) == float or  x.find('%') == -1:
        return ""
    else:
        split_val = x.split('%')
        pos_neg_ind = -1 if split_val[1] == " Sell" else 1
        return  round(int(split_val[0])/10)*pos_neg_ind

# %%
# create a new column to set the derived values
sp500_df['BuySell_rating'] = [convertOpinionBuySellToratingScale(x) for x in sp500_df['Opinion']]
sp500_df[['Opinion', 'BuySell_rating']].head(10)
# Out:
#     Opinion BuySell_rating
# 0   88% Buy              9
# 1   8% Sell             -1
# 2  88% Sell             -9
# 3   56% Buy              6
# 4   80% Buy              8
# 5   40% Buy              4
# 6  100% Buy             10
# 7    8% Buy              1
# 8  72% Sell             -7
# 9  100% Buy             10

# %%
# Display the modified dataframe column hearders,  values
# change setting to display all the columns
pd.set_option('display.max_columns', None)

sp500_df.head(100)
# Out:
#    Symbol                       Name     Market Cap  Price Earnings    EPS  \
# 0       A       Agilent Technologies    42235084000           26.32   5.37
# 1     AAL       American Airlines Gp     9009457000            5.24   2.64
# 2    AAPL                  Apple Inc  2620000000000           26.30   6.42
# 3    ABBV                 Abbvie Inc   301000000000           15.11  11.11
# 4    ABNB            Airbnb Inc Cl A   105000000000           36.85   4.31
# ..    ...                        ...            ...             ...    ...
# 95   CINF       Cincinnati Financial    19037930000           19.91   6.04
# 96     CL  Colgate-Palmolive Company    72236128000           27.06   3.23
# 97    CLX             Clorox Company    18112030000           25.14   5.83
# 98    CMA               Comerica Inc     6974274000            6.85   7.70
# 99  CMCSA             Comcast Corp A   162000000000           10.36   3.97
#
#      Net Income  Beta  Dividend Div Yield  Extended Hr Last Price  \
# 0    1240000000  1.11     0.922     0.64%                  144.12
# 1     822000000  1.57       NaN     0.00%                   13.75
# 2   96995000000  1.27     0.960     0.57%                  169.47
# 3    4863000000  0.58     5.990     3.52%                  169.99
# 4    4792000000  1.25       NaN     0.00%                  161.77
# ..          ...   ...       ...       ...                     ...
# 95   1843000000  0.63     3.060     2.52%                  121.52
# 96   2300000000  0.42     1.920     2.18%                   87.88
# 97    149000000  0.43     4.780     3.28%                  145.92
# 98    881000000  1.27     2.840     5.40%                   52.64
# 99  15389000000  0.98     1.180     2.89%                   40.95
#
#     Extended Hr Change  Extended Hr %Change      Time  Last Price  Change  \
# 0                  0.00               0.00%  4/5/2024      144.12    2.78
# 1                 -0.01              -0.07%  4/5/2024       13.76   -0.07
# 2                 -0.11              -0.06%  4/5/2024      169.58    0.76
# 3                 -0.01              -0.01%  4/5/2024      170.00    2.10
# 4                  0.00               0.00%  4/5/2024      161.77    2.93
# ..                  ...                 ...       ...         ...     ...
# 95                 0.00               0.00%  4/5/2024      121.52    1.24
# 96                 0.00               0.00%  4/5/2024       87.88    0.48
# 97                -0.02              -0.01%  4/5/2024      145.94   -0.61
# 98                 0.00               0.00%  4/5/2024       52.64   -0.12
# 99                 0.05               0.12%  4/5/2024       40.90   -0.21
#
#       %Chg    Opinion 20D Relative Strength 20D His Vol  20D Avg Vol  52W Low  \
# 0    1.97%    88% Buy                53.65%      17.81%      1711680    96.80
# 1   -0.51%    8% Sell                41.11%      37.04%     28192830    10.86
# 2    0.45%   88% Sell                40.73%      21.24%     64083164   159.78
# 3    1.25%    56% Buy                41.80%      24.03%      6737740   130.96
# 4    1.84%    80% Buy                53.66%      22.45%      4004745   103.55
# ..     ...        ...                   ...         ...          ...      ...
# 95   1.03%   100% Buy                61.04%      17.39%      1231420    95.01
# 96   0.55%    80% Buy                54.56%      10.00%      3690580    67.62
# 97  -0.42%    24% Buy                42.94%      23.85%      1217825   114.68
# 98  -0.23%   100% Buy                52.41%      31.42%      2113480    28.40
# 99  -0.51%  100% Sell                38.56%      17.22%     21333824    36.38
#
#     52W High  Wtd Alpha YTD %Chg 1M %Chg 3M %Chg 52W %Chg  \
# 0     151.58      12.11    3.66%  -0.16%  10.39%    4.37%
# 1      19.08       2.39    0.15%  -6.20%   1.18%   -0.94%
# 2     199.62      -3.00  -11.92%  -0.32%  -6.40%    3.55%
# 3     182.89      10.74    9.70%  -5.11%   4.85%    5.72%
# 4     170.10      43.69   18.83%   1.53%  18.97%   40.25%
# ..       ...        ...      ...     ...     ...      ...
# 95    124.35      20.13   17.46%   8.54%  13.19%    9.20%
# 96     90.37      19.87   10.25%   1.33%   9.88%   16.61%
# 97    178.21      -6.28    2.35%  -2.64%   3.29%   -7.29%
# 98     57.39      24.40   -5.68%   1.74%  -6.85%   31.86%
# 99     47.46       1.94   -6.73%  -2.76%  -4.97%    7.86%
#
#                    Sector          ISIN    Volume BuySell_rating
# 0       Health Technology  US00846U1016    1.656M              9
# 1          Transportation  US02376R1023   30.632M             -1
# 2   Electronic Technology  US0378331005   42.104M             -9
# 3       Health Technology  US00287Y1091     7.03M              6
# 4       Consumer Services  US0090661010    2.226M              8
# ..                    ...           ...       ...            ...
# 95                Finance  US1720621010  424.039K             10
# 96  Consumer Non-Durables  US1941621039     3.48M              8
# 97  Consumer Non-Durables  US1890541097  740.152K              2
# 98                Finance  US2003401070    1.229M             10
# 99      Consumer Services  US20030N1019   22.833M            -10
#
# [100 rows x 31 columns]

# %% [markdown]
# - What changes were made to the data?
# - Are there any legal or regulatory guidelines for your data or project topic?
# - What risks could be created based on the transformations done?
# - Did you make any assumptions in cleaning/transforming the data?
# - How was your data sourced / verified for credibility?
# - Was your data acquired in an ethical way?
# - How would you mitigate any of the ethical implications you have identified?
#
# -------------------

# %% [markdown]
# Following are the Changes made to the data
#
# - The 4th,  12th and 18th   column header  were renamed, , Changed "P/E" to "Price Earnings", FChanged  "%Chg (Ext)" to "Extended Hr %Change" and changed "20D Rel Str" to "20D Relative Strength"
# - Checked for any NaN values in the critical columns; identified NaN values in non-critical columns, therefore no records were removed.
# - Changed float numbers to int64 to eliminate exponential notation in the 'Market Cap' column.
# - Values in the 'Volume' column contained a special character '?" within the values. Adjustments were made to eliminate this special character.
# - The 'Opinion' column contained buy and sell suggestions with a percentage magnitude. A new column titled 'Buy Sell Rating' was created to generate a positive or negative rating ranging from 1 to 10 based on the values in the 'Opinion' column.

# %% [markdown]
# Stock information is subject to the regulations of the country where the stock is listed. Companies are typically mandated to disclose specific information to both investors and the public. This information is made available through stock exchanges for public access and scrutiny.

# %% [markdown]
# The transformations made were cosmetic and did not change any values or the primary purpose of the data.

# %% [markdown]
# No assumptions were while transforming the data.

# %% [markdown]
# The data was obtained from a reputable website, which in turn sources it from government-approved stock exchanges. This data is disseminated across numerous commercial websites via feeds received from authoritative channels.

# %% [markdown]
# Apart from the 'Opinion' column, which offers buy or sell suggestions, the transformed column is derived from the same. These buy and sell recommendations come with a disclaimer, advising investors to use them as guidance and conduct their due diligence before making any decisions to buy or sell the stock instrument.
